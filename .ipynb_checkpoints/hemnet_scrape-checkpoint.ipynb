# %%
import requests
from bs4 import BeautifulSoup

# %%
import requests
from bs4 import BeautifulSoup
search = 'https://www.hemnet.se/salda/bostader?location_ids%5B%5D=925970&location_ids%5B%5D='\
            '925968&location_ids%5B%5D=925969&location_ids%5B%5D=473448&location_ids%5B%5D='\
            '898472&location_ids%5B%5D=473362&item_types%5B%5D=bostadsratt&sold_age=all'
    
result = requests.get(search)
src = result.content
soup = BeautifulSoup(src)

urls = []
for li_tag in soup.find_all('li'):
    for div_tag in li_tag.find_all('div'):
        a_tag = div_tag.find('a')
        if a_tag != None:
            urls.append(a_tag.attrs['href'])

# %%
urls = [x for x in urls if x.startswith("https://www.hemnet.se/")]

# %%
#closing_price = soup.find_all('span', class_="sold-property__price-value")
#closing_price = price[0].contents[0].strip(' kr').replace(u"\xa0", "")

# %%
urls
# Out:
# ['https://www.hemnet.se/salda/bostadsratt-2rum-stockholm-vasastan-stockholms-kommun-sveavagen-134-1092175',
#  'https://www.hemnet.se/salda/bostadsratt-2,5rum-kungsholmen-stockholms-kommun-sankt-goransgatan-96,-4tr-1092134',
#  'https://www.hemnet.se/salda/bostadsratt-2rum-kungsholmen-stockholms-kommun-igeldammsgatan-10-1092035',
#  'https://www.hemnet.se/salda/bostadsratt-4rum-kungsholmen-stockholms-kommun-svarvargatan-7-1092004',
#  'https://www.hemnet.se/salda/bostadsratt-3rum-vasastan-norrmalm-stockholms-kommun-dobelnsgatan-53,-3-tr-1091986',
#  'https://www.hemnet.se/salda/bostadsratt-4rum-birkastan-vasastan-stockholms-kommun-rorstrandsgatan-56a-1091985',
#  'https://www.hemnet.se/salda/bostadsratt-3rum-norrmalm-stockholms-kommun-regeringsgatan-86-1091806',
#  'https://www.hemnet.se/salda/bostadsratt-2rum-vasastan-stockholms-kommun-dalagatan-24-1091801',
#  'https://www.hemnet.se/salda/bostadsratt-3rum-ostermalm-stockholms-kommun-artillerigatan-50-1091643',
# ...

# %%
result = requests.get(urls[0])
src = result.content
soup = BeautifulSoup(src)

columns = []
for a in soup.find_all('dt', text=lambda s: s != "Prisutveckling"):
    columns.append(a.contents[0])
columns.append('Slutpris')

# %%
df = pd.DataFrame(columns=columns)

# %%
all_values = []
for url in urls:
    values = []
    result = requests.get(url)
    src = result.content
    soup = BeautifulSoup(src)
    for a in soup.find_all('dd'):
        value = a.contents[0].strip(' kr').strip(' kr/m²').strip(' rum')\
                             .strip(' kr/mån').strip(' kr/å').strip('\n').replace(u"\xa0", "")
        
        if 'Brf' not in value and value != '':
            values.append(value)

    closing_price = soup.find_all('span', class_="sold-property__price-value")
    closing_price = closing_price[0].contents[0].strip(' kr').replace(u"\xa0", "")
    values.append(closing_price)
    all_values.append(values)

# %%
df = pd.DataFrame(all_values)
df.columns = columns

# %%
temp = df.loc[df.Slutpris.isna()]
temp.loc[:, 'Slutpris'] = temp.loc[:, 'Byggår'].values
temp.loc[:, 'Byggår'] = temp.loc[:,'Driftskostnad'].values
temp.loc[:, 'Driftskostnad'] = None

# %%
temp2 = df.loc[~df.Slutpris.isna()]

# %%
data = pd.concat([temp, temp2])

# %%
all_values = []
features = []

temp_result = requests.get(urls[0])
src = temp_result.content
soup = BeautifulSoup(src)

features = []
for div_tag in soup.find_all('div'):
    dt_tag = div_tag.find('dt')
    if (dt_tag != None):
        features.append(dt_tag.get_text())
        
features = features[7:]


for url in urls:
    temp_result = requests.get(url)
    src = temp_result.content
    soup = BeautifulSoup(src)

    values = []
    for div_tag in soup.find_all('div'):
        dd_tag = div_tag.find('dd')
        if dd_tag != None:
            values.append(dd_tag.get_text())
        
    values = [x.replace(u"\xa0", "") for x in values]
    
    values = values[7:]
    all_values.append(values)

# %%
pd.DataFrame(all_values)
# Out:
#                      0                        1      2         3  \
# 0             Lägenhet              Bostadsrätt  1 rum   40,5 m²
# 1             Lägenhet              Bostadsrätt  3 rum     84 m²
# 2             Lägenhet              Bostadsrätt  3 rum     77 m²
# 3             Lägenhet              Bostadsrätt  3 rum     62 m²
# 4             Lägenhet              Bostadsrätt  3 rum     88 m²
# 5             Lägenhet              Bostadsrätt  5 rum  112,5 m²
# 6             Lägenhet              Bostadsrätt  2 rum     46 m²
# 7             Lägenhet              Bostadsrätt  4 rum  106,4 m²
# 8             Lägenhet              Bostadsrätt  2 rum     52 m²
# 9             Lägenhet              Bostadsrätt  2 rum     66 m²
# 10            Lägenhet              Bostadsrätt  4 rum   92,5 m²
# 11  Par-/kedje-/radhus              Bostadsrätt  5 rum    120 m²
# 12            Lägenhet              Bostadsrätt  1 rum   23,5 m²
# ...

# %%
def Booli_ScrapeObjects(page, object_info):
    request = requests.get(page)
    soup = BeautifulSoup(request.text,'lxml')
    links = soup.select("a[href*=/annons/]")

    for j, row in enumerate(links):
        info = row.contents[5].text.split("\n")
        while '' in info:
            info.remove('')
            info[0] = info[0].strip(" kr")
            info[1] = info[1].strip(" kr/m²")
            info[2] = info[2].strip(" kr/mån")
            object_info.append(info)
        try:
            info.insert(0,"https://www.booli.se" + links[j]["href"])
            #FETCHING ADDRESS, # ROOMS AND M2
            request_apartment = requests.get(info[0])
            soup_apartment = BeautifulSoup(request_apartment.text, 'lxml')
            address = soup_apartment.findAll('span',
            class_ = 'property__header__street-address')
            address = address[0].contents[0].strip("\n\t\t")
            info.append(address)
            size = soup_apartment.findAll('span',
            class_ = 'property__base-info__title__size')
            size = size[0].contents[0].strip("\n\t").split(",")
            rooms = size[0].strip(" rum")
            m2 = size[1].strip(" m²")
            info.append(rooms)
            info.append(m2)
        except:
            info.insert(0, "Unknown")   #Link
            info.append("Unknown")      #Address
            info.append("Unknown")      #Rooms
            info.append("Unknown")      #m2
            info.append("Unknown")      #Estimate
            continue
return object_info

# %%
values = [x.replace(u"\xa0", "") for x in values]

# %%
[features, values]
# Out:
# [['Bostadstyp', 'Upplåtelseform', 'Antal rum', 'Boarea', 'Avgift', 'Pris/m²'],
#  ['Lägenhet', 'Bostadsrätt', '4 rum', '93 m²', '5078kr/mån', '36290kr/m²']]

# %%
values
# Out:
# ['Lägenhet', 'Bostadsrätt', '4 rum', '93 m²', '5078kr/mån', '36290kr/m²']
